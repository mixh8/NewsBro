# %%
from __future__ import unicode_literals, print_function
import os
import nltk
from nltk.tokenize import word_tokenize
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from transformers import pipeline
from spacy.lang.en import English
nltk.download('punkt')

MAX_TOKENS = 880
MIN_WORD_PER_SENTENCE = 15
SUMMARY_MAX_LENGTH = 240
SUMMARY_MIN_LENGTH = 30
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")


def getNumTokens(article):
    return len(word_tokenize(article))

def lexRank(article, sentenceCount):
    # Create a parser for the article text
    parser = PlaintextParser.from_string(article, Tokenizer("english"))

    # Create a LexRank summarizer
    summarizer = LexRankSummarizer()

    # Get the summary
    summary = summarizer(parser.document, sentenceCount)

    summaryText = []
    for sentence in summary:
        summaryText.append(str(sentence))
    return " ".join(summaryText)


def bart(article, maxLength=SUMMARY_MAX_LENGTH, minLength=SUMMARY_MIN_LENGTH):
    return summarizer(article, max_length=maxLength, min_length=minLength, do_sample=False)


def getArticles():
    folder_path = "articles"

    # Get the list of all files in the specified folder
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

    # Filter out only the txt files
    txt_files = [f for f in files if f.endswith(".txt")]

    # Create a dictionary to store the content of each text file
    file_contents = {}

    # Loop through each txt file and read its content
    for txt_file in txt_files:
        file_path = os.path.join(folder_path, txt_file)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            publisher = txt_file[:-4]
            file_contents[publisher] = content

    return file_contents

def summarizeArticle(article):
    numTokens = getNumTokens(article)
    lexRankedArticle = article
    i = 0
    while numTokens > MAX_TOKENS:
        numSentences = MAX_TOKENS / (MIN_WORD_PER_SENTENCE + i)
        lexRankedArticle = lexRank(article, numSentences)
        numTokens = getNumTokens(lexRankedArticle)
        i += 1
    return bart(lexRankedArticle)

print(summarizeArticle(getArticles()['reuters']))
# Out:
# [nltk_data] Downloading package punkt to /Users/gino/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [{'summary_text': "OpenAI's Chief Technology Officer Mira Murati will serve as interim CEO. OpenAI kicked off the generative AI craze last November by releasing ChatGPT. Greg Brockman, OpenAI president and co-founder, quit the company."}]

# %%
class Summary:
    text = ""
    publisher = "NewsBroInc."
    def __init__(self, text, publisher):
        self.text = text
        self.publisher = publisher
    
def getSummarizedArticles():
    articles = getArticles()
    summaries = []
    for article in articles:
        print("trying: ",article)
        cur = Summary(summarizeArticle(articles[article])[0]['summary_text'], article)
        summaries.append(cur)
        print(cur.text)
    return summaries

allSummaries = getSummarizedArticles()
# Out:
# trying:  barrons
# OpenAI CEO Sam Altman has left the company. The company says he was not "consistently candid in his communications with the board" President Greg Brockman said he had decided to leave the company, as well.
# trying:  crunchbase
# OpenAI co-founder and AI wunderkind Sam Altman is out as the company’s CEO. Mira Murati, the company's chief technology officer, has been named interim CEO. The company also announced Greg Brockman will be stepping down as chairman of the board.
# trying:  businessinsider
# Sam Altman is out as CEO of AI company OpenAI. The board of the AI company says it "no longer has confidence in his ability to continue leading OpenAI" Altman was "not consistently candid in his communications," the board said.
# trying:  jazeera
# Sam Altman, the Silicon Valley CEO behind the artificial intelligence-powered chatbots ChatGPT and GPT-4, has been abruptly fired by his company. Microsoft-backed OpenAI said on Friday that its board of directors decided on the ‘leadership transition’ after losing confidence in Altman’s ability to lead the company.
# trying:  politico
# Sam Altman was removed from his role as CEO of OpenAI Friday. Altman is considered the face of the new wave of artificial intelligence. He has pushed Congress to pass laws to mitigate the catastrophic risks of AI.
# trying:  axios
# Microsoft learned that OpenAI was ousting CEO Sam Altman just a minute before the news was shared with the world. Microsoft is ChatGPT maker OpenAI's closest partner and has deeply tied its fortunes to the AI startup. CTO Mira Murati was named interim CEO.
# trying:  sfstandard
# Mira Murati, the company's chief technology officer, will take over as interim CEO, effective immediately. Altman was let go after a review process that found that "he was not consistently candid in his communications with the board"
# trying:  mashable
# Sam Altman published a statement on X, formerly known as Twitter, less than two hours after he was fired from his position as OpenAI CEO. "i loved my time at openai it was transformative for me personally, and hopefully the world a little bit. will have more to say about what’s next later," he said.
# trying:  sfchronicle
# Sam Altman, the CEO of OpenAI, was pushed out by the company's board of directors. The company's chief technology officer, Mira Murati, will serve as interim CEO “effective immediately,” the company said. Greg Brockman will be stepping down as the company’s board chair but remain at the company.
# trying:  nytimes
# Sam Altman, the high-profile chief executive of OpenAI, was pushed out of the company by its board of directors. The move set off a reshuffling at Open AI, a groundbreaking A.I. company and the maker of the popular chatbot ChatGPT. It was not immediately clear what had led to the board’s decision.
# trying:  bbc
# Sam Altman, co-founder of AI firm OpenAI, was sacked on Friday. Board of directors said he had not been "consistently candid in communications" with them. There are swirling rumours but, so far, no further facts.
# trying:  arstechnica
# OpenAI fired CEO Sam Altman on Friday. President Greg Brockman and three senior scientists also resigned. The move blindsided key investor Microsoft, reportedly making CEO Satya Nadella furious.
# trying:  reuters
# OpenAI's Chief Technology Officer Mira Murati will serve as interim CEO. OpenAI kicked off the generative AI craze last November by releasing ChatGPT. Greg Brockman, OpenAI president and co-founder, quit the company.
# trying:  france24
# OpenAI cofounder Greg Brockman was pushed from the company's board and put out late in the day that he quit. Altman became a tech world sensation with the release nearly a year ago of ChatGPT, an artificial intelligence chatbot. Microsoft has invested billions of dollars in OpenAI and has woven its technology into its offerings.
# trying:  dailybeast
# Co-founder and president of OpenAI abruptly quit late Friday, hours after the shocking firing of CEO Sam Altman just hours earlier. Altman’s departure follows a deliberative review process by the board, which concluded that he was not consistently candid in his communications with the board. The board appointed Chief Technology Officer Mira Murati to serve as interim CEO.
# trying:  nymag
# Sam Altman, the co-founder and CEO of OpenAI, was fired on Friday. The company said the board no longer has confidence in his ability to continue leading OpenAI. Altman was considered to be the leader of the burgeoning artificial-intelligence revolution. OpenAI’s chief technology officer, Mira Murati, will be interim CEO.
# trying:  geekwire
# Sam Altman is leaving OpenAI, the company he helped start in 2015 and led as CEO. CTO Mira Murati will serve as interim CEO. Greg Brockman, who helped start the company with Altman, is stepping down as chairman of the board.
# trying:  foxnews
# OpenAI co-founder Greg Brockman said he is "shocked and saddened" by the company's board of directors' decision to fire CEO Sam Altman. The board said in a press release that Altman was leaving OpenAI because of his lack of communication with the board. Brockman announced he was quitting as company president based on the board's decision.
# trying:  wired
# CEO of AI company OpenAI resigns after losing the confidence of its board. Greg Brockman, who cofounded OpenAI with Altman, will also step down from his role as chair of the company’s board. Board's announcement said that a review of Altman's conduct “concluded that he was not consistently candid’
# trying:  forbes
# Sam Altman, founder of OpenAI, resigns as CEO of AI firm. Board says he was not "consistently candid in his communications with the board, hindering its ability to exercise its responsibilities" Cofounder Greg Brockman was to leave his role as chairman of the board.
# trying:  npr
# Sam Altman, co-founder of chatbot maker ChatGPT, pushed out as CEO of OpenAI. He was "not consistently candid in his communications" with the board of directors, company says. Mira Murati, OpenAI's chief technology officer, will take over as interim CEO.
# trying:  endagadget
# Sam Altman and Greg Brockman are "shocked and saddened by what the board did" Altman's ouster followed internal arguments on whether OpenAI was developing artificial intelligence technology in a safe manner. Brockman chose to quit on his own. Employees were reportedly very much aware that turmoil was brewing within the organization.
# trying:  pbs
# The board of ChatGPT-maker Open AI says it has pushed out its co-founder and CEO Sam Altman. A review found he was “not consistently candid in his communications’ with the board. Mira Murati, OpenAI’s chief technology officer, has been appointed interim CEO.
# trying:  sfgate
# OpenAI's board of directors has fired CEO and co-founder Sam Altman. The announcement comes just a day after Altman spoke on behalf of the company in a panel at APEC. Chief Technology Officer Mira Murati will step in as interim CEO.
# trying:  cnn
# OpenAI announced Mira Murati, the company’s chief technology officer, will serve as interim CEO. ‘it was transformative for me personally, and hopefully the world a little bit. most of all i loved working with such talented people,’ Altman said.
# trying:  dw
# Sam Altman, founder and CEO of OpenAI, has left the company. He will be replaced temporarily by Chief Technology Officer Mira Murati. Altman acknowledged he was leaving OpenAI in a post on X.
# trying:  rollingstone
# Sam Altman has been removed as CEO of OpenAI, according to a company statement. The surprise firing has set off a flurry of questions about why a startup currently positioned for a valuation of up to $90 billion would cut ties with its chief executive. The company’s president Greg Brockman, who earlier stepped down from the board, announced he was quitting.
# trying:  bloomberg
# Artificial intelligence is one of the most commonly debated issues in the technology community. The concerns boil down to a truly unfathomable one: Will AI kill us all?
# trying:  theverge
# Sam Altman has been fired as CEO of OpenAI, the company announced on Friday. Altman is a co-founder of the company, which kick-started the current AI arms race with last year’s release of ChatGPT. Chief technology officer Mira Murati will be the interim CEO, effective immediately.
# trying:  washingtonpost
# OpenAI CEO Sam Altman was ousted Friday. The board said it had lost confidence in his ability to lead the company. Altman’s ouster follows “a deliberative review process by the board,” the board said.
# trying:  computerworld
# OpenAI CEO Sam Altman has been fired by the board of directors. Altman was a key figure in the creation of landmark generative AI application ChatGPT. Board Chairman Greg Brockman will also leave his role as a result of the shakeup.

# %%
import tensorflow as tf
import tensorflow_hub as hub

embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

def areBulletsSimilar(sentence1, sentence2):

    embeddings1 = embed([sentence1])
    embeddings2 = embed([sentence2])

    similarity = tf.reduce_sum(tf.multiply(embeddings1, embeddings2)).numpy()

    # print(similarity)
    return similarity > 0.5

def getSentencesFromRawText(input_text):
    # Load the English NLP model from spacy
    nlp = English()

    # Process the text using spacy
    doc = nlp(input_text)
    nlp.add_pipe('sentencizer')

    doc = nlp(input_text)
    sentences = [sent.text.strip() for sent in doc.sents]

    return sentences

class Bullet:
    text = ""
    publisher = "NewsBroInc."
    def __init__(self, text, publisher):
        self.text = text
        self.publisher = publisher
    def __str__(self):
        return f"""{self.publisher}: {self.text}"""
    
def getAllBullets(summaries):
    allBullets = []
    for summary in summaries:
        publisher = summary.publisher
        curBullets = getSentencesFromRawText(summary.text)
        for bulletText in curBullets:
            allBullets.append(Bullet(bulletText, publisher)) 
    return allBullets
allBullets =  getAllBullets(allSummaries)


def getFinalClusters(allBullets):
    output = [[allBullets[0]]]
    for i in range(1, len(allBullets)):
        cur = allBullets[i]
        foundSimilarInstance = False
        for i in range (len(output)):
            if areBulletsSimilar(cur.text, output[i][0].text):
                foundSimilarInstance = True
                output[i].append(cur)
                break
        if foundSimilarInstance == False:
            output.append([cur])

    return output
clusters = getFinalClusters(allBullets)

def getFinalOutput(clusters):
    sortedList = sorted(clusters, key=len)
    sortedList.reverse()
    return sortedList[:5]

finalOutput = (getFinalOutput(clusters))
for bullet in finalOutput:
    print(bullet[0].text)
# Out:
# OpenAI CEO Sam Altman has left the company.
# The company says he was not "consistently candid in his communications with the board" President Greg Brockman said he had decided to leave the company, as well.
# OpenAI's Chief Technology Officer Mira Murati will serve as interim CEO.
# Altman is considered the face of the new wave of artificial intelligence.
# Greg Brockman, who cofounded OpenAI with Altman, will also step down from his role as chair of the company’s board.
